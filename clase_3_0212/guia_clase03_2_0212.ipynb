# %% [markdown]
# <font size="4" color="rgb(128, 128, 0)">3. Funciones II</font>

# %% [markdown]
# * Argumentos y paŕametros

# %% [markdown]
# ### Argumentos y Parámetros

# %% [markdown]
# #### Definicion

# %% [markdown]
# En la definición de la función, las variables o valores se denominan parámetros:

# %%
# definicion
# numero1 y numero2 son los parametros de la función suma

def suma(numero1, numero2):
  return numero1 + numero2

# %% [markdown]
# En la llamada se los denomina argumentos.

# %%
# llamada a la función
# nro1 y nro2 son los argumentos de la funcion suma

nro1 = 23
nro2 = 8
suma(nro1, nro2)
# Out:
# 31

# %% [markdown]
# #### Pasando valores -- Argumentos por posición

# %% [markdown]
# Cuando se envían argumentos a una función, se reciben por orden en los parámetros definidos:

# %%
def suma(numero1, numero2):
  print(f"numero1: {numero1}")
  print(f"numero2: {numero2}")

  return numero1 + numero2

# %%
resultado = suma(5, 7)
print(resultado)
# Out:
# numero1: 5
# numero2: 7
# 12

# %%
suma(7,5)

# %%
def resta(numero1, numero2):
  print(f"numero1: {numero1}")
  print(f"numero2: {numero2}")

  return numero1 - numero2

# %%
resultado = resta(7, 5)
print(resultado)

# %%
resta(5, 7)

# %% [markdown]
# #### Argumentos por nombre

# %%
def resta(numero1, numero2):
  print(f"numero1: {numero1}")
  print(f"numero2: {numero2}")

  return numero1 - numero2

# %%
resta(numero2=7, numero1=14)
# Out:
# numero1: 14
# numero2: 7
# 7

# %%
resta(numero1=20, numero2=30)
# Out:
# numero1: 20
# numero2: 30
# -10

# %%
def resta(numero1, numero2, numero3):
  print(f"numero1: {numero1}")
  print(f"numero2: {numero2}")
  print(f"numero3: {numero3}")

  return numero1 - numero2 - numero3


resultado = resta(numero3=7, numero1=5, numero2=100)
# Out:
# numero1: 5
# numero2: 100
# numero3: 7

# %% [markdown]
# #### Llamada sin argumentos

# %%
def suma(numero1=1, numero2=1):

  print(f"numero1: {numero1}")
  print(f"numero2: {numero2}")

  return numero1 + numero2

# %%
# llamamos a la funcion suma sin argumentos
suma(6,6)
# Out:
# numero1: 6
# numero2: 6
# 12

# %%
suma()
# Out:
# numero1: 1
# numero2: 1
# 2

# %%
# valores por defecto -- calc

def calc(numero1, numero2, operacion="+"):

  if operacion == "+":
    resultado = numero1 + numero2
  elif operacion == "-":
    resultado = numero1 - numero2
  else:
    print("operacion invalida")
    resultado = None

  return resultado

# %%
calc(5,5, "-")
# Out:
# 0

# %%
calc(operacion="+", numero1=34, numero2=10)

# %%
calc("+",23,45)
# Out:
# operacion invalida

# %%
# ver orden y opcionales
def calc(numero1, numero2, operacion="+"):
  pass

# %%
def suma(a,b):
  return a + b

# %%
suma("a", "b")
# Out:
# 'ab'

# %%
suma([0,1], [9, 6])
# Out:
# [0, 1, 9, 6]

# %% [markdown]
# Preguntas❓

# %% [markdown]
# #### Argumentos por Valor y Referencia

# %% [markdown]
# Si hablamos de argumentos tenemos que tener algo en cuenta:
# Cuando **enviamos información a una función** generalmente estos datos se envían por **valor**.
# Eso significa que **se crea una copia dentro de la función de los valores que enviamos en sus propias variables**.

# %%
def incrementador(numero):
  numero += 1
  return

numero = 50

print(f"El valor de numero antes de la funcion es: {numero}")
print("/********/")

incrementador(numero)

print("/********/")
print(f"El valor de numero despues del llamado a la funcion es: {numero}")
# Out:
# El valor de numero antes de la funcion es: 50
# /********/
# /********/
# El valor de numero despues del llamado a la funcion es: 50

# %% [markdown]
#  **Pero**, hay casos excepcionales, las colecciones, **listas, diccionarios, conjuntos**. Estos datos se envían por **referencia**.

# %% [markdown]
# Que significa que se envian por referencia?

# %% [markdown]
# Significa que, en lugar de una copia dentro de la función, **estaremos manejando el dato original**, y si lo modificamos también se verá reflejado en el exterior, es decir, en el conjunto original y no en una copia en la función. Esto debido a que hacen referencia a la variable externa, algo así como un acceso directo.

# %%
lista = [0, 1, 2, 3, 4, 5, 6, 7]

def agregar_dato(lista, dato):
  if len(lista) < 10:
    lista.append(dato)
  else:
    print("La lista no tiene mas capacidad")

  return

valor = 8

print(lista)
agregar_dato(lista, valor)
print(lista)
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7]
# [0, 1, 2, 3, 4, 5, 6, 7, 8]

# %%
# Ejemplo con diccionario

datos = {
    "nombre": "Juan"
}

def cambiar(dato):
  dato["nombre"] = "Pablo"
  return

print(datos)
cambiar(datos)
print(datos)
# Out:
# {'nombre': 'Juan'}
# {'nombre': 'Pablo'}

# %%
# y si no quiero que se modifique?

datos = {
    "nombre": "Juan"
}

def cambiar(dato):
  dato = dato.copy()
  dato["nombre"] = "Pablo"
  print("adentro de la funcion", dato)
  return

print(datos)
cambiar(datos)
print(datos)
# Out:
# {'nombre': 'Juan'}
# adentro de la funcion {'nombre': 'Pablo'}
# {'nombre': 'Juan'}

# %%
dir(dict)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
def incrementador(numero):
  numero += 1
  return numero

numero = 50
numero = incrementador(numero)
print(numero)
# Out:
# 51

# %% [markdown]
# #### Resumen:

# %% [markdown]
# **Paso por valor**: se crea una copia local de la variable dentro de la función.
#
# Los tipos simples **se pasan por valor**: Enteros, flotantes, cadenas, lógicos…

# %% [markdown]
# **Paso por referencia**: Se maneja directamente la variable, los cambios realizados dentro de la función le afectarán también fuera.
#
# Los tipos compuestos **se pasan por referencia**: Listas, diccionarios, tuplas, conjuntos...

# %% [markdown]
# __Entonces__:
#
# ¿Es posible que de alguna forma le digamos a Python cuándo queremos pasar un argumento por referencia o por valor?

# %% [markdown]
# **Respuesta:**

# %%
# Ejemplo : Argumento valor por referencia
def incrementador(numero):
  numero += 1

  return numero

var = 5

var = incrementador(var)
print(var)

foo = 7
foo = incrementador(foo)
print(foo)

# %% [markdown]
# Preguntas❓

# %% [markdown]
# #### Argumentos indeterminados

# %% [markdown]
# #### *args

# %% [markdown]
# Permiten definir funciones cuyo número de argumentos es variable. Es decir, podemos definir funciones genéricas que no aceptan un número determinado de parámetros, sino que se “adaptan” al número de argumentos con los que son llamados.

# %%
def suma(*args):
  resultado = 0

  for valor in args:
    resultado += valor

  return resultado

# %%
suma(1,2)
# Out:
# 3

# %%
suma(1,2,3,4)
# Out:
# 10

# %%
suma(1,2,3,4,1,5)
# Out:
# 16

# %% [markdown]
# #### *kwargs

# %% [markdown]
# Los **kwargs nos permiten dar un nombre a cada argumento de entrada, pudiendo acceder a ellos dentro de la función a través de un diccionario.

# %%
def suma(**kwargs):
  resultado = 0

  for clave, valor in kwargs.items():
    print(f"arg clave: {clave} -- arg valor: {valor}")
    resultado += valor

  return resultado

# %%
suma(nroA=1,nroB=2, numero5=23)
# Out:
# arg clave: nroA -- arg valor: 1
# arg clave: nroB -- arg valor: 2
# arg clave: numero5 -- arg valor: 23
# 26

# %% [markdown]
# __Nota__: args y kwargs se llaman asi por convencion, pero podrian tener otro nombre

# %% [markdown]
# ### Multiples return

# %%
def dividir(numero1, numero2):

  if numero2 == 0:
    return None

  return numero1 / numero2

# %%
nro1 = 10
nro2 = 2
print(dividir(nro1, nro2))
# Out:
# 5.0

# %% [markdown]
# Preguntas❓

# %% [markdown]
# ### Typehints

# %% [markdown]
# * Disponible en python desde la version 3.5
# * No es obligatorio!!!
# * Especificar los tipo de dato de los argumentos de una funcion
# * Especificar el tipo de dato que retorna una funcion
# * Chequeo estatico - no en runtime - [mypy](https://mypy-lang.org/)

# %%
def suma(numero1, numero2):
  return numero1 + numero2

# %%
def suma(numero1: int, numero2: int)-> int:
  print("suma")
  return numero1 + numero2

# %%
suma(45,67)
# Out:
# 112

# %%
suma(7.9, 6)   # cuando corro mypy aca me da un error, tienen que ser enteros
# Out:
# suma
# 13.9

# %%
def saludar(nombre: str)->str:
  return f"Hola, {nombre}"

# %%
def resta(a: float, b: float) -> float:
    return a - b

# %%
#from typing import List

def total_marks(marks: list[int]) -> int:
    return sum(marks)

# %%
# from typing import Tuple

def get_student() -> tuple[str, int]:
    return "Alice", 25

# %%
# from typing import Dict
from typing import Any

def count_fruits(fruit_basket: dict[str, Any]) -> int:
    return sum(fruit_basket.values())

# %%
from typing import tuple

def get_student() -> Tuple[str, int]:
    return "Alice", 25

# %%
from typing import Optional

def find_user(user_id: int) -> Optional[str]:
    if user_id == 1:
        return "Alice"
    else:
        return None

# %% [markdown]
# ### Docstrings

# %% [markdown]
# Documentar funciones

# %%
def factorial(numero: int)-> int:
  """
  Esta funcion calcula el factorial del numero que se le pasa
  como argumento.
  """

  if numero == 1:
    return numero

  numero = numero * factorial(numero - 1)

  return numero

# %%
help(factorial)
# Out:
# Help on function factorial in module __main__:
#
# factorial(numero: int) -> int
#     Esta funcion calcula el factorial del numero que se le pasa
#     como argumento.

# %%
factorial()

# %% [markdown]
# Preguntas❓

# %%
# ver map
map(function, iterable)
